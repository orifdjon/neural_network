# %%
import pandas as pd
import matplotlib
import theano
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
from neupy import algorithms, layers, init, environment, plots
from neupy.exceptions import StopTraining
from sklearn import datasets, cross_validation
# Out:
# /home/nattramn/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
all_data=pd.read_csv("../all_data.csv", index_col=0)
all_data=np.array(all_data)
eps=0.000001
number_of_epochs=200

# %%
test_errors=[]
def signal(net):
    test_errors.append(((net.predict(test_params)-test_target)**2).sum()/len(test_target))
    if len(net.errors)>20:
        if abs(net.errors[len(net.errors)-1]-net.errors[len(net.errors)-2]) < eps:
            raise StopTraining("Training has been interrupted")

# %%
np.random.seed(57)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             layers.Tanh(5, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(5, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(5, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("1 architechture learn error mean "+str(np.array(learn_error_task).mean()))
print("1 architechture learn error std "+str(np.array(learn_error_task).std()))
print("1 architechture test error mean "+str(np.array(test_error_task).mean()))
print("1 architechture test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 30.29 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      4.0268 |      1.3068 |      116 ms |
# |          50 |     0.12067 |     0.12857 |       12 ms |
# |         100 |     0.11943 |     0.12746 |       12 ms |
# |         150 |      0.1174 |     0.12499 |       12 ms |
# |         200 |     0.11703 |      0.1246 |       12 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.63 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      6.2962 |      1.0234 |       70 ms |
# |          50 |     0.12442 |     0.13194 |       12 ms |
# |         100 |     0.12126 |     0.12811 |       12 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #146 stopped. Training has been interrupted
# |         146 |     0.12066 |     0.12802 |       13 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.32 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.61759 |     0.34117 |       72 ms |
# |          50 |     0.12124 |     0.12976 |       12 ms |
# |         100 |     0.11854 |     0.12641 |       18 ms |
# |         150 |     0.11771 |     0.12624 |       26 ms |
# |         200 |     0.11729 |     0.12576 |       13 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.20 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1437 |     0.70203 |       12 ms |
# |          50 |     0.12326 |     0.12649 |       23 ms |
# |         100 |     0.12099 |     0.12444 |       12 ms |
# |         150 |     0.11976 |     0.12271 |       12 ms |
# |         200 |     0.11902 |       0.122 |       12 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.21 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.9482 |      1.7385 |       25 ms |
# |          50 |     0.12675 |     0.12873 |       12 ms |
# |         100 |     0.12474 |     0.12802 |       12 ms |
# |         150 |     0.12201 |     0.12595 |       25 ms |
# |         200 |     0.12011 |       0.124 |       13 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.20 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1428 |      1.0446 |       33 ms |
# |          50 |     0.12458 |     0.13108 |       12 ms |
# |         100 |     0.12185 |     0.12767 |       13 ms |
# |         150 |     0.12108 |     0.12749 |       12 ms |
# |         200 |     0.12055 |     0.12734 |       25 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.52 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.0594 |      0.9884 |       70 ms |
# |          50 |     0.12345 |     0.12971 |       12 ms |
# |         100 |     0.12154 |     0.12806 |       24 ms |
# |         150 |     0.11963 |     0.12635 |       12 ms |
# |         200 |     0.11891 |     0.12629 |       12 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.55 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.0636 |     0.90018 |       70 ms |
# |          50 |     0.12446 |     0.13139 |       12 ms |
# |         100 |     0.12207 |     0.12865 |       24 ms |
# |         150 |     0.12041 |     0.12802 |       12 ms |
# |         200 |     0.11956 |     0.12798 |       12 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.62 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |       2.829 |     0.92736 |       73 ms |
# |          50 |      0.1244 |     0.12984 |       12 ms |
# |         100 |     0.12224 |     0.12788 |       12 ms |
# |         150 |      0.1212 |     0.12656 |       12 ms |
# |         200 |     0.12021 |     0.12584 |       12 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.97 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.2674 |      1.1488 |       84 ms |
# |          50 |     0.12357 |     0.13095 |       12 ms |
# |         100 |      0.1217 |     0.12931 |       13 ms |
# |         150 |     0.12027 |     0.12804 |       12 ms |
# |         200 |     0.11842 |     0.12694 |       13 ms |
# ---------------------------------------------------------
#
# 1 architechture learn error mean 0.11917499474391044
# 1 architechture learn error std 0.00122551117857018
# 1 architechture test error mean 0.12234856900798241
# 1 architechture test error std 0.006364725502577516

# %%
np.random.seed(58)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             layers.Tanh(5, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(5, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("2 architechture learn error mean "+str(np.array(learn_error_task).mean()))
print("2 architechture learn error std "+str(np.array(learn_error_task).std()))
print("2 architechture test error mean "+str(np.array(test_error_task).mean()))
print("2 architechture test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.31 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      0.9984 |     0.81919 |       15 ms |
# |          50 |     0.12715 |      0.1261 |       16 ms |
# |         100 |     0.12391 |     0.12317 |       16 ms |
# |         150 |     0.12324 |     0.12304 |       16 ms |
# |         200 |     0.12227 |     0.12385 |       16 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.79 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.1769 |     0.75618 |       91 ms |
# |          50 |     0.12426 |     0.12192 |       15 ms |
# |         100 |      0.1215 |     0.12058 |       16 ms |
# |         150 |     0.11975 |     0.11971 |       16 ms |
# |         200 |     0.11778 |     0.11722 |       21 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.43 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.7073 |      1.1089 |       42 ms |
# |          50 |     0.12516 |     0.12609 |       16 ms |
# |         100 |     0.12265 |     0.12445 |       16 ms |
# |         150 |     0.12005 |     0.12242 |       15 ms |
# |         200 |     0.11887 |     0.12116 |       15 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.55 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.3209 |     0.94055 |       91 ms |
# |          50 |     0.12388 |     0.12436 |       15 ms |
# |         100 |     0.12157 |     0.12335 |       16 ms |
# |         150 |     0.12041 |     0.12188 |       15 ms |
# |         200 |     0.11903 |     0.12059 |       16 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.92 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      4.3455 |      3.0229 |       15 ms |
# |          50 |     0.12694 |     0.12563 |       16 ms |
# |         100 |     0.12472 |     0.12369 |       97 ms |
# |         150 |     0.12394 |     0.12325 |       32 ms |
# |         200 |     0.12269 |     0.12231 |       32 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.85 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.6668 |     0.69182 |       30 ms |
# |          50 |      0.1256 |     0.12487 |       14 ms |
# |         100 |     0.12294 |     0.12328 |       18 ms |
# |         150 |     0.12148 |     0.12342 |       35 ms |
# |         200 |      0.1208 |     0.12312 |       32 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.36 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      5.2518 |      1.0999 |      107 ms |
# |          50 |     0.12566 |     0.12458 |       15 ms |
# |         100 |     0.12221 |     0.12317 |       16 ms |
# |         150 |     0.11988 |     0.12156 |       16 ms |
# |         200 |     0.11869 |     0.12055 |       17 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.10 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      4.8019 |     0.80752 |       94 ms |
# |          50 |     0.12412 |      0.1207 |       15 ms |
# |         100 |     0.12122 |     0.12067 |       16 ms |
# |         150 |     0.12021 |     0.11962 |       18 ms |
# |         200 |     0.11945 |     0.11863 |       17 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.10 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.9392 |     0.69368 |       88 ms |
# |          50 |     0.12491 |     0.12451 |       16 ms |
# |         100 |     0.12225 |     0.12338 |       15 ms |
# |         150 |     0.12101 |     0.12287 |       18 ms |
# |         200 |     0.11937 |      0.1218 |       25 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.81 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.81853 |     0.53279 |      115 ms |
# |          50 |     0.12584 |       0.128 |       15 ms |
# |         100 |     0.12273 |      0.1254 |       16 ms |
# |         150 |     0.12096 |     0.12261 |       16 ms |
# |         200 |     0.11929 |     0.12237 |       16 ms |
# ---------------------------------------------------------
#
# 2 architechture learn error mean 0.11982337287525724
# 2 architechture learn error std 0.0015103769832588545
# 2 architechture test error mean 0.12080605918362923
# 2 architechture test error std 0.010212857798433445

# %%
np.random.seed(17)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             layers.Tanh(5, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("3 architechture learn error mean "+str(np.array(learn_error_task).mean()))
print("3 architechture learn error std "+str(np.array(learn_error_task).std()))
print("3 architechture test error mean "+str(np.array(test_error_task).mean()))
print("3 architechture test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.02 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.80314 |     0.37512 |       41 ms |
# |          50 |     0.12535 |     0.12727 |       19 ms |
# |         100 |     0.12076 |      0.1236 |       19 ms |
# |         150 |      0.1197 |     0.12207 |       20 ms |
# |         200 |     0.11815 |     0.12051 |       19 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.44 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.0705 |       1.084 |       30 ms |
# |          50 |     0.12529 |     0.12529 |       18 ms |
# |         100 |     0.12036 |     0.12087 |       27 ms |
# |         150 |      0.1184 |      0.1206 |       20 ms |
# |         200 |     0.11783 |     0.12124 |       20 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.86 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.44709 |      0.3634 |      115 ms |
# |          50 |     0.12592 |     0.12832 |       22 ms |
# |         100 |     0.12481 |     0.12779 |       29 ms |
# |         150 |     0.12328 |     0.12651 |       19 ms |
# |         200 |     0.12284 |     0.12558 |       20 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 20.27 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1335 |      0.7227 |      121 ms |
# |          50 |     0.12621 |     0.12822 |       26 ms |
# |         100 |     0.12358 |     0.12592 |       21 ms |
# |         150 |     0.12237 |     0.12482 |       23 ms |
# |         200 |     0.12154 |     0.12354 |       20 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 21.99 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.2679 |     0.94178 |      165 ms |
# |          50 |       0.125 |     0.12738 |       24 ms |
# |         100 |     0.12199 |     0.12476 |       19 ms |
# |         150 |     0.11996 |     0.12269 |       19 ms |
# |         200 |     0.11744 |      0.1222 |       45 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 20.87 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      3.0174 |     0.71612 |      113 ms |
# |          50 |     0.12353 |     0.12681 |       18 ms |
# |         100 |      0.1216 |     0.12481 |       19 ms |
# |         150 |     0.11969 |     0.12271 |       21 ms |
# |         200 |     0.11906 |     0.12259 |       20 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 20.09 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.5051 |      1.1949 |      120 ms |
# |          50 |      0.1265 |     0.12651 |       20 ms |
# |         100 |     0.12284 |     0.12259 |       30 ms |
# |         150 |     0.12055 |     0.12109 |       20 ms |
# |         200 |      0.1198 |     0.12009 |       19 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.11 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.6699 |      1.0281 |      114 ms |
# |          50 |      0.1248 |     0.12924 |       19 ms |
# |         100 |     0.12174 |     0.12606 |       20 ms |
# |         150 |     0.11931 |     0.12358 |       20 ms |
# |         200 |      0.1183 |     0.12282 |       62 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.82 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.2936 |     0.74853 |      154 ms |
# |          50 |     0.12583 |     0.12483 |       18 ms |
# |         100 |     0.12223 |       0.121 |       19 ms |
# |         150 |     0.11926 |     0.11836 |       21 ms |
# |         200 |     0.11696 |     0.11771 |       20 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.91 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      3.8542 |     0.81872 |      114 ms |
# |          50 |     0.12542 |     0.12542 |       19 ms |
# |         100 |     0.12347 |     0.12334 |       19 ms |
# |         150 |     0.12178 |     0.12199 |       39 ms |
# |         200 |     0.12125 |     0.12224 |       19 ms |
# ---------------------------------------------------------
#
# 1 architechture learn error mean 0.11931728513940161
# 1 architechture learn error std 0.0018733411158978926
# 1 architechture test error mean 0.12188538970988813
# 1 architechture test error std 0.0068616333028495985

# %%
np.random.seed(62)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             layers.Tanh(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("4 architechture learn error mean "+str(np.array(learn_error_task).mean()))
print("4 architechture learn error std "+str(np.array(learn_error_task).std()))
print("4 architechture test error mean "+str(np.array(test_error_task).mean()))
print("4 architechture test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.11 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      0.8297 |     0.41372 |      127 ms |
# |          50 |     0.12411 |     0.12864 |       22 ms |
# |         100 |     0.12137 |     0.12588 |       23 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #139 stopped. Training has been interrupted
# |         139 |      0.1206 |     0.12458 |       24 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.38 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.77519 |     0.29668 |      131 ms |
# |          50 |     0.12256 |     0.12797 |       26 ms |
# |         100 |      0.1205 |     0.12615 |       23 ms |
# |         150 |     0.11906 |      0.1239 |       50 ms |
# |         200 |     0.11759 |     0.12124 |       24 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.05 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      3.1058 |     0.49976 |      138 ms |
# |          50 |     0.12237 |     0.13051 |       26 ms |
# |         100 |     0.12011 |     0.12646 |       23 ms |
# |         150 |     0.11856 |     0.12446 |       23 ms |
# |         200 |     0.11632 |     0.12163 |       24 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.19 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.4877 |     0.73801 |       43 ms |
# |          50 |     0.12197 |     0.13072 |       24 ms |
# |         100 |     0.12011 |     0.12702 |       25 ms |
# |         150 |     0.11938 |     0.12702 |       24 ms |
# |         200 |     0.11848 |     0.12465 |       25 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.31 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.5523 |      0.9055 |       22 ms |
# |          50 |     0.12299 |     0.13052 |       23 ms |
# |         100 |     0.12107 |     0.12738 |       24 ms |
# |         150 |     0.11967 |     0.12507 |       24 ms |
# |         200 |     0.11779 |     0.12276 |       24 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.66 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.3261 |     0.74634 |       43 ms |
# |          50 |     0.12471 |     0.12861 |       24 ms |
# |         100 |     0.12233 |     0.12651 |       25 ms |
# |         150 |     0.11998 |     0.12241 |       25 ms |
# |         200 |     0.11888 |     0.12183 |       25 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.31 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.5555 |     0.63622 |       45 ms |
# |          50 |     0.12378 |     0.13117 |       23 ms |
# |         100 |     0.12181 |     0.12681 |       23 ms |
# |         150 |     0.12104 |     0.12651 |       23 ms |
# |         200 |     0.12038 |     0.12545 |       23 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.34 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1348 |     0.31853 |      130 ms |
# |          50 |     0.12285 |     0.13123 |       22 ms |
# |         100 |     0.11968 |     0.12704 |       25 ms |
# |         150 |     0.11806 |     0.12469 |       24 ms |
# |         200 |     0.11718 |     0.12393 |       24 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.71 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      3.8325 |     0.74034 |      170 ms |
# |          50 |     0.12265 |     0.12853 |       23 ms |
# |         100 |     0.12054 |     0.12622 |       23 ms |
# |         150 |     0.11982 |     0.12607 |       24 ms |
# |         200 |     0.11877 |     0.12394 |       24 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.92 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.6893 |      1.0874 |      147 ms |
# |          50 |     0.12464 |     0.12835 |       24 ms |
# |         100 |     0.12267 |      0.1263 |       23 ms |
# |         150 |     0.12173 |     0.12456 |       24 ms |
# |         200 |     0.11991 |     0.12116 |       25 ms |
# ---------------------------------------------------------
#
# 4 architechture learn error mean 0.11859142675991989
# 4 architechture learn error std 0.001336808542202975
# 4 architechture test error mean 0.12108883992272486
# 4 architechture test error std 0.0065638344833779715

# %%
np.random.seed(57)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             layers.Tanh(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("5 architechture learn error mean "+str(np.array(learn_error_task).mean()))
print("5 architechture learn error std "+str(np.array(learn_error_task).std()))
print("5 architechture test error mean "+str(np.array(test_error_task).mean()))
print("5 architechture test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.60 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.3511 |      0.8345 |      145 ms |
# |          50 |     0.12765 |     0.12526 |       28 ms |
# |         100 |     0.12474 |      0.1253 |       29 ms |
# |         150 |     0.12264 |     0.12335 |       28 ms |
# |         200 |     0.12118 |     0.12279 |       28 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.49 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.4022 |     0.51275 |      145 ms |
# |          50 |     0.12846 |      0.1261 |       26 ms |
# |         100 |     0.12633 |     0.12348 |       26 ms |
# |         150 |     0.12346 |     0.12305 |       28 ms |
# |         200 |     0.12201 |     0.12355 |       28 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.33 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      6.2348 |      2.0049 |       25 ms |
# |          50 |     0.12552 |     0.12379 |       29 ms |
# |         100 |     0.12344 |      0.1221 |       28 ms |
# |         150 |       0.122 |     0.12202 |       59 ms |
# |         200 |     0.12041 |     0.12106 |       30 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.51 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      4.0787 |     0.75311 |      155 ms |
# |          50 |     0.12414 |      0.1235 |       55 ms |
# |         100 |     0.12001 |     0.12124 |       27 ms |
# |         150 |     0.11783 |     0.12066 |       42 ms |
# |         200 |     0.11685 |     0.12021 |       65 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.94 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.95324 |     0.49276 |      151 ms |
# |          50 |     0.12672 |     0.12241 |       27 ms |
# |         100 |     0.12249 |     0.12185 |       29 ms |
# |         150 |     0.11994 |     0.12097 |       28 ms |
# |         200 |     0.11915 |     0.12074 |       29 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.23 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.0237 |     0.61342 |      148 ms |
# |          50 |     0.12416 |     0.12245 |       27 ms |
# |         100 |     0.12153 |     0.12245 |       28 ms |
# |         150 |     0.11885 |     0.12141 |       28 ms |
# |         200 |     0.11789 |      0.1199 |       28 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.67 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.3466 |     0.77016 |      154 ms |
# |          50 |     0.12543 |     0.12561 |       28 ms |
# |         100 |     0.12029 |     0.12192 |       29 ms |
# |         150 |     0.11866 |     0.12068 |       28 ms |
# |         200 |      0.1179 |     0.12092 |       29 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.79 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      6.3741 |     0.61375 |      161 ms |
# |          50 |     0.12647 |     0.12401 |       57 ms |
# |         100 |     0.12253 |     0.12268 |       29 ms |
# |         150 |     0.12008 |     0.11997 |       30 ms |
# |         200 |     0.11871 |      0.1192 |       28 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.50 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.4554 |     0.38844 |      150 ms |
# |          50 |     0.12438 |     0.12763 |       54 ms |
# |         100 |     0.12174 |     0.12558 |       33 ms |
# |         150 |     0.12019 |     0.12481 |       28 ms |
# |         200 |      0.1177 |      0.1225 |       42 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 22.28 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.9295 |      1.0308 |      148 ms |
# |          50 |     0.12545 |     0.12282 |       26 ms |
# |         100 |     0.12107 |     0.12102 |       28 ms |
# |         150 |     0.12011 |     0.12062 |       27 ms |
# |         200 |     0.11946 |     0.12086 |       28 ms |
# ---------------------------------------------------------
#
# 5 architechture learn error mean 0.11912793473418179
# 5 architechture learn error std 0.001572629580211288
# 5 architechture test error mean 0.12095623696594895
# 5 architechture test error std 0.00796279841880711

# %%
np.random.seed(61)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             layers.Tanh(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("6 architechture learn error mean "+str(np.array(learn_error_task).mean()))
print("6 architechture learn error std "+str(np.array(learn_error_task).std()))
print("6 architechture test error mean "+str(np.array(test_error_task).mean()))
print("6 architechture test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.78 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.87301 |     0.24007 |      172 ms |
# |          50 |     0.12734 |     0.11374 |       36 ms |
# |         100 |     0.12351 |     0.11019 |       37 ms |
# |         150 |     0.12163 |     0.11136 |       38 ms |
# |         200 |     0.12096 |     0.11184 |       76 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.56 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.96632 |     0.44679 |      176 ms |
# |          50 |     0.12767 |     0.11825 |       34 ms |
# |         100 |     0.12392 |     0.11522 |       36 ms |
# |         150 |     0.12068 |     0.11335 |       48 ms |
# |         200 |     0.11939 |     0.11373 |       36 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.27 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      4.8703 |      0.7589 |      175 ms |
# |          50 |     0.12852 |     0.11817 |       35 ms |
# |         100 |      0.1258 |     0.11609 |       36 ms |
# |         150 |     0.12234 |     0.11369 |       37 ms |
# |         200 |     0.12077 |     0.11333 |       36 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.38 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.0733 |     0.46752 |      168 ms |
# |          50 |     0.12795 |     0.11626 |       36 ms |
# |         100 |     0.12515 |     0.11475 |       41 ms |
# |         150 |     0.12394 |     0.11384 |       35 ms |
# |         200 |      0.1232 |     0.11322 |       52 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.86 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |       2.028 |     0.85988 |      190 ms |
# |          50 |     0.12932 |      0.1162 |       34 ms |
# |         100 |     0.12669 |      0.1144 |       71 ms |
# |         150 |     0.12341 |     0.11325 |       36 ms |
# |         200 |     0.12097 |     0.11254 |       38 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.93 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.2714 |     0.42688 |      170 ms |
# |          50 |     0.12792 |      0.1172 |       36 ms |
# |         100 |     0.12526 |     0.11548 |       38 ms |
# |         150 |     0.12335 |     0.11386 |       36 ms |
# |         200 |     0.12112 |     0.11237 |       83 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.51 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.9153 |     0.60926 |      167 ms |
# |          50 |     0.12827 |     0.11656 |       35 ms |
# |         100 |     0.12616 |     0.11569 |       34 ms |
# |         150 |     0.12286 |     0.11262 |       37 ms |
# |         200 |     0.12136 |     0.11308 |       36 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.38 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1505 |     0.58229 |      183 ms |
# |          50 |     0.12944 |     0.11739 |       35 ms |
# |         100 |     0.12583 |     0.11401 |       37 ms |
# |         150 |     0.12467 |     0.11316 |       38 ms |
# |         200 |     0.12295 |     0.11253 |       38 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.75 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      3.9694 |     0.92389 |      172 ms |
# |          50 |     0.12847 |     0.11822 |       36 ms |
# |         100 |     0.12541 |     0.11708 |       36 ms |
# |         150 |     0.12345 |     0.11458 |       48 ms |
# |         200 |     0.12153 |      0.1144 |       36 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.73 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.6959 |     0.76576 |      165 ms |
# |          50 |     0.12741 |     0.11778 |       36 ms |
# |         100 |     0.12538 |     0.11529 |       38 ms |
# |         150 |      0.1222 |      0.1147 |       38 ms |
# |         200 |     0.11977 |     0.11524 |       39 ms |
# ---------------------------------------------------------
#
# 6 architechture learn error mean 0.12120158187607273
# 6 architechture learn error std 0.0011316189952549514
# 6 architechture test error mean 0.12044579536844599
# 6 architechture test error std 0.003298445741551371

# %%
np.random.seed(60)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             layers.Sigmoid(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Sigmoid(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Sigmoid(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("Logistic learn error mean "+str(np.array(learn_error_task).mean()))
print("Logistic learn error std "+str(np.array(learn_error_task).std()))
print("Logistic test error mean "+str(np.array(test_error_task).mean()))
print("Logistic test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.72 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.9567 |      1.0006 |      164 ms |
# |          50 |     0.12191 |     0.13456 |       49 ms |
# |         100 |     0.12008 |     0.13195 |       34 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #120 stopped. Training has been interrupted
# |         120 |     0.11982 |     0.13107 |       34 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.45 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.1038 |     0.99094 |      167 ms |
# |          50 |     0.12298 |     0.13599 |       32 ms |
# |         100 |     0.12166 |     0.13515 |       32 ms |
# |         150 |     0.12038 |     0.13212 |       37 ms |
# |         200 |      0.1189 |     0.13147 |       33 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.17 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.2785 |     0.98441 |      170 ms |
# |          50 |     0.12338 |     0.13774 |       34 ms |
# |         100 |     0.12135 |     0.13784 |       34 ms |
# |         150 |     0.12013 |     0.13496 |       33 ms |
# |         200 |     0.11935 |     0.13473 |       82 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.94 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |       1.908 |      1.0134 |      162 ms |
# |          50 |     0.12956 |     0.13738 |       53 ms |
# |         100 |      0.1228 |       0.132 |       34 ms |
# |         150 |      0.1219 |     0.13085 |       34 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #199 stopped. Training has been interrupted
# |         199 |     0.12145 |     0.13009 |       52 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 20.19 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.7366 |       1.001 |      159 ms |
# |          50 |     0.12689 |     0.13795 |       50 ms |
# |         100 |     0.12325 |     0.13555 |       34 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #113 stopped. Training has been interrupted
# |         113 |     0.12307 |     0.13505 |       34 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.15 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      6.3634 |      1.0027 |      159 ms |
# |          50 |     0.13105 |     0.13791 |       35 ms |
# |         100 |     0.12294 |     0.13124 |       70 ms |
# |         150 |     0.12051 |     0.12812 |       68 ms |
# |         200 |     0.11858 |     0.12754 |       32 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.97 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.3714 |      1.0048 |      157 ms |
# |          50 |     0.12406 |     0.13031 |       36 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #63 stopped. Training has been interrupted
# |          63 |     0.12388 |     0.13056 |       36 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.48 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.8004 |     0.99478 |      161 ms |
# |          50 |      0.1268 |     0.13657 |       33 ms |
# |         100 |     0.12426 |     0.13405 |       35 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #130 stopped. Training has been interrupted
# |         130 |     0.12394 |     0.13338 |       34 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.74 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.6084 |     0.99891 |      179 ms |
# |          50 |     0.13005 |     0.14107 |       52 ms |
# |         100 |     0.12184 |     0.13332 |       33 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #146 stopped. Training has been interrupted
# |         146 |     0.12111 |     0.13268 |       32 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 20.65 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1101 |     0.99873 |      156 ms |
# |          50 |     0.12401 |     0.13508 |       34 ms |
# |         100 |     0.12191 |     0.13287 |       33 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #139 stopped. Training has been interrupted
# |         139 |     0.12066 |     0.13127 |       33 ms |
#
# Logistic learn error mean 0.12107495689329864
# Logistic learn error std 0.0018936325160477973
# Logistic test error mean 0.1251829230715749
# Logistic test error std 0.009622825048642591

# %%
np.random.seed(24)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             layers.Tanh(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Tanh(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("Tanh learn error mean "+str(np.array(learn_error_task).mean()))
print("Tanh learn error std "+str(np.array(learn_error_task).std()))
print("Tanh test error mean "+str(np.array(test_error_task).mean()))
print("Tanh test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.48 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.97462 |     0.50084 |      177 ms |
# |          50 |     0.12337 |     0.12583 |       38 ms |
# |         100 |     0.12131 |     0.12456 |      106 ms |
# |         150 |     0.11918 |     0.12229 |       86 ms |
# |         200 |     0.11845 |     0.12213 |       39 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.22 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |       1.839 |     0.25611 |      166 ms |
# |          50 |     0.12365 |     0.12835 |       34 ms |
# |         100 |     0.12125 |     0.12539 |       38 ms |
# |         150 |     0.12012 |     0.12367 |       80 ms |
# |         200 |     0.11748 |     0.12216 |       40 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.34 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.51987 |     0.24308 |      168 ms |
# |          50 |     0.12713 |     0.12855 |       34 ms |
# |         100 |     0.12119 |     0.12196 |       36 ms |
# |         150 |     0.11944 |     0.12107 |       74 ms |
# |         200 |     0.11843 |     0.12044 |       36 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.20 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      5.4567 |     0.74952 |      202 ms |
# |          50 |     0.12359 |     0.12443 |       35 ms |
# |         100 |     0.12086 |      0.1232 |       40 ms |
# |         150 |     0.11935 |     0.12135 |       76 ms |
# |         200 |     0.11858 |     0.12194 |       38 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.40 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      3.0303 |      0.7505 |      167 ms |
# |          50 |      0.1257 |     0.12706 |       46 ms |
# |         100 |     0.12327 |     0.12469 |       34 ms |
# |         150 |     0.12118 |     0.12227 |       36 ms |
# |         200 |      0.1194 |     0.12251 |       37 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.65 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.4105 |      1.0716 |       56 ms |
# |          50 |     0.12347 |     0.12516 |       36 ms |
# |         100 |     0.12123 |     0.12328 |       41 ms |
# |         150 |     0.11867 |     0.12068 |       37 ms |
# |         200 |     0.11643 |     0.11835 |       38 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.71 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.4405 |     0.56345 |      171 ms |
# |          50 |     0.12482 |     0.12752 |       35 ms |
# |         100 |     0.11988 |     0.12312 |       36 ms |
# |         150 |     0.11832 |     0.12201 |       36 ms |
# |         200 |     0.11744 |     0.12148 |       40 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.14 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.2747 |     0.94695 |      165 ms |
# |          50 |     0.12475 |     0.12481 |       36 ms |
# |         100 |     0.12277 |     0.12333 |       36 ms |
# |         150 |      0.1207 |     0.12254 |       37 ms |
# |         200 |     0.11895 |     0.12163 |       38 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.50 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |       1.554 |     0.26295 |      171 ms |
# |          50 |     0.12551 |     0.12785 |       35 ms |
# |         100 |     0.12174 |     0.12433 |       40 ms |
# |         150 |     0.12044 |     0.12415 |       41 ms |
# |         200 |      0.1191 |     0.12324 |       40 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.47 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.2923 |     0.84273 |      223 ms |
# |          50 |     0.12348 |     0.12806 |      116 ms |
# |         100 |     0.12105 |     0.12616 |       77 ms |
# |         150 |     0.11757 |     0.12177 |       38 ms |
# |         200 |      0.1165 |     0.12222 |       37 ms |
# ---------------------------------------------------------
#
# Tanh learn error mean 0.11807662300448045
# Tanh learn error std 0.0010006418279270026
# Tanh test error mean 0.12148499318513677
# Tanh test error std 0.00836086043472165

# %%
np.random.seed(98)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             layers.Linear(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("Linear learn error mean "+str(np.array(learn_error_task).mean()))
print("Linear learn error std "+str(np.array(learn_error_task).std()))
print("Linear test error mean "+str(np.array(test_error_task).mean()))
print("Linear test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.08 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.4483 |      0.3443 |       54 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #21 stopped. Training has been interrupted
# |          21 |     0.15992 |     0.16631 |       14 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.43 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      3.0134 |     0.17741 |       39 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #21 stopped. Training has been interrupted
# |          21 |     0.15971 |     0.16497 |       14 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 16.48 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |       4.123 |     0.29588 |       38 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #21 stopped. Training has been interrupted
# |          21 |     0.15896 |     0.16626 |       55 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.12 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      5.3621 |      4.0051 |       47 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #21 stopped. Training has been interrupted
# |          21 |     0.15928 |     0.16845 |       64 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.37 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.5104 |     0.67459 |       42 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #21 stopped. Training has been interrupted
# |          21 |     0.16042 |     0.16436 |       13 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.34 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      0.7299 |     0.29986 |       41 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #21 stopped. Training has been interrupted
# |          21 |      0.1599 |     0.15767 |       35 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.90 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1233 |     0.37548 |       51 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #21 stopped. Training has been interrupted
# |          21 |     0.15837 |     0.16713 |       15 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 20.03 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      5.4444 |       21.68 |       19 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #21 stopped. Training has been interrupted
# |          21 |     0.15972 |     0.16599 |       13 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.87 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.50457 |     0.20883 |       45 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #21 stopped. Training has been interrupted
# |          21 |     0.15724 |     0.16547 |       59 ms |
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.89 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      3.8685 |     0.28241 |       41 ms |
# ---------------------------------------------------------
# [TRAIN] Epoch #21 stopped. Training has been interrupted
# |          21 |      0.1602 |     0.16397 |       52 ms |
#
# Linear learn error mean 0.15937209602948027
# Linear learn error std 0.0009105537207018401
# Linear test error mean 0.1611746550760602
# Linear test error std 0.007785993834091591

# %%
import theano.tensor as T
class Softsign(layers.ActivationLayer):
    def activation_function(self, input_value):
        return input_value/(T.abs_(input_value)+1)
np.random.seed(113)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             Softsign(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             Softsign(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             Softsign(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("Softsign learn error mean "+str(np.array(learn_error_task).mean()))
print("Softsign learn error std "+str(np.array(learn_error_task).std()))
print("Softsign test error mean "+str(np.array(test_error_task).mean()))
print("Softsign test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 30.12 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.0547 |     0.91477 |      915 ms |
# |          50 |     0.12417 |     0.12434 |       23 ms |
# |         100 |     0.12059 |     0.12235 |       24 ms |
# |         150 |     0.11768 |     0.12056 |       64 ms |
# |         200 |     0.11653 |     0.12046 |       23 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 21.82 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |       1.261 |      0.5597 |      112 ms |
# |          50 |     0.12377 |     0.12361 |       29 ms |
# |         100 |     0.12029 |      0.1193 |       27 ms |
# |         150 |     0.11849 |      0.1188 |       55 ms |
# |         200 |     0.11718 |      0.1179 |       28 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 25.26 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.8401 |     0.84158 |      132 ms |
# |          50 |     0.12513 |     0.12439 |       25 ms |
# |         100 |     0.12231 |     0.12214 |       25 ms |
# |         150 |     0.11983 |     0.12135 |       28 ms |
# |         200 |     0.11872 |     0.12094 |       24 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 20.41 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.89399 |     0.62498 |       16 ms |
# |          50 |     0.12273 |     0.12204 |       22 ms |
# |         100 |       0.119 |     0.11895 |       22 ms |
# |         150 |     0.11669 |     0.11775 |       32 ms |
# |         200 |     0.11514 |     0.11688 |       32 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 22.66 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.85875 |      0.5934 |      113 ms |
# |          50 |     0.12336 |     0.12021 |       21 ms |
# |         100 |     0.11937 |     0.11828 |       21 ms |
# |         150 |     0.11754 |     0.11668 |       22 ms |
# |         200 |      0.1162 |     0.11613 |       23 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 21.51 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      4.4075 |      1.0226 |      110 ms |
# |          50 |     0.12426 |     0.12234 |       52 ms |
# |         100 |     0.11924 |     0.11986 |       23 ms |
# |         150 |     0.11736 |     0.11867 |       22 ms |
# |         200 |     0.11556 |     0.11621 |       22 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.19 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1013 |     0.77819 |      109 ms |
# |          50 |     0.12376 |      0.1241 |       22 ms |
# |         100 |     0.12074 |     0.12109 |       22 ms |
# |         150 |     0.11869 |     0.12082 |       21 ms |
# |         200 |     0.11668 |     0.11952 |       25 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.92 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1068 |     0.88662 |      109 ms |
# |          50 |     0.12202 |     0.12388 |       22 ms |
# |         100 |     0.11884 |     0.12047 |       21 ms |
# |         150 |      0.1177 |     0.11957 |       28 ms |
# |         200 |     0.11613 |     0.11981 |       22 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 22.36 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.2412 |     0.98222 |       16 ms |
# |          50 |     0.12377 |     0.12229 |       22 ms |
# |         100 |     0.12046 |     0.11923 |       22 ms |
# |         150 |     0.11916 |     0.11884 |       22 ms |
# |         200 |     0.11818 |     0.11806 |       22 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 22.12 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      6.9781 |     0.88582 |      109 ms |
# |          50 |     0.12276 |     0.12302 |       21 ms |
# |         100 |     0.11955 |      0.1196 |       21 ms |
# |         150 |     0.11807 |     0.11934 |       21 ms |
# |         200 |     0.11716 |      0.1189 |       21 ms |
# ---------------------------------------------------------
#
# Softsign learn error mean 0.11674876007118654
# Softsign learn error std 0.0010503131563227913
# Softsign test error mean 0.12035763329327501
# Softsign test error std 0.006501549564220993

# %%
np.random.seed(183)
np.random.shuffle(all_data)
learn_error_task=[]
test_error_task=[]
for train_indices, test_indices in cross_validation.KFold(len(all_data), n_folds=10, shuffle=True):
    test_errors=[]
    tmp_data=all_data[train_indices]
    test_data=all_data[test_indices]
    learn_data=tmp_data[0:int(0.7*len(tmp_data))]
    validation_data=tmp_data[int(0.7*len(tmp_data)):len(tmp_data)]
    learn_params=learn_data[:,[0,1]]
    learn_target=learn_data[:,[2]]
    test_params=test_data[:,[0,1]]
    test_target=test_data[:,[2]]
    validation_params=validation_data[:,[0,1]]
    validation_target=validation_data[:,[2]]
    bpnet = algorithms.QuasiNewton(
         connection=[
             layers.Input(2),
             layers.Softplus(10, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Softplus(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Softplus(15, weight=init.XavierNormal(), bias=init.XavierNormal()),
             layers.Linear(1, weight=init.XavierNormal(), bias=init.XavierNormal()),
         ],
         update_function='bfgs',
         error='mse',
         h0_scale=1,
         epoch_end_signal=signal,
         shuffle_data=True,
         show_epoch=50,
         verbose=True
     )
    bpnet.train(learn_params, learn_target, validation_params, validation_target, epochs=number_of_epochs)
    learn_error_task.append(bpnet.errors.last())
    test_error_task.append(test_errors[len(test_errors)-1])
print("Softplus learn error mean "+str(np.array(learn_error_task).mean()))
print("Softplus learn error std "+str(np.array(learn_error_task).std()))
print("Softplus test error mean "+str(np.array(test_error_task).mean()))
print("Softplus test error std "+str(np.array(test_error_task).std()))
# Out:
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 21.14 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.4524 |      1.0558 |      354 ms |
# |          50 |     0.13461 |     0.13654 |       58 ms |
# |         100 |      0.1262 |     0.13095 |       58 ms |
# |         150 |     0.12462 |     0.12928 |       60 ms |
# |         200 |     0.12321 |     0.12765 |       65 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.47 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.99327 |     0.83387 |      419 ms |
# |          50 |     0.12582 |     0.13474 |       65 ms |
# |         100 |     0.12242 |     0.13225 |       68 ms |
# |         150 |     0.11972 |     0.12967 |       59 ms |
# |         200 |     0.11891 |     0.12935 |       67 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 17.83 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1323 |     0.94008 |      340 ms |
# |          50 |     0.13098 |      0.1282 |       58 ms |
# |         100 |     0.12626 |     0.12499 |       59 ms |
# |         150 |     0.12287 |      0.1227 |       59 ms |
# |         200 |     0.12191 |     0.12198 |       60 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.27 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      3.0671 |      1.0713 |      342 ms |
# |          50 |     0.12895 |     0.13081 |       61 ms |
# |         100 |     0.12409 |     0.12807 |       59 ms |
# |         150 |     0.12255 |     0.12723 |       63 ms |
# |         200 |     0.12096 |      0.1261 |       60 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.80 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4897, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.2403 |      1.0326 |      353 ms |
# |          50 |     0.12654 |     0.13134 |       63 ms |
# |         100 |     0.12334 |      0.1287 |       62 ms |
# |         150 |     0.12167 |     0.12713 |      142 ms |
# |         200 |     0.12083 |     0.12699 |       62 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.31 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      6.1486 |     0.94384 |      362 ms |
# |          50 |     0.13326 |     0.13588 |      364 ms |
# |         100 |     0.12479 |     0.13157 |       63 ms |
# |         150 |     0.12276 |     0.12972 |      126 ms |
# |         200 |     0.12178 |     0.12871 |       65 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 20.45 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1414 |     0.91975 |      412 ms |
# |          50 |     0.13289 |     0.13353 |       78 ms |
# |         100 |     0.12667 |      0.1294 |      100 ms |
# |         150 |     0.12462 |     0.12898 |       86 ms |
# |         200 |     0.12236 |     0.12629 |       60 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 18.10 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      1.1687 |      0.9327 |      480 ms |
# |          50 |     0.12859 |     0.13048 |       73 ms |
# |         100 |     0.12427 |     0.12841 |       69 ms |
# |         150 |     0.12222 |     0.12627 |      101 ms |
# |         200 |     0.12106 |     0.12549 |       72 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 20.97 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |       1.722 |      1.0855 |      363 ms |
# |          50 |     0.12953 |     0.13169 |      145 ms |
# |         100 |     0.12246 |     0.12693 |       69 ms |
# |         150 |     0.12146 |     0.12638 |       81 ms |
# |         200 |     0.11979 |     0.12562 |       63 ms |
# ---------------------------------------------------------
#
#
# Main information
#
# [ALGORITHM] QuasiNewton
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = signal
# [OPTION] show_epoch = 50
# [OPTION] shuffle_data = True
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
# [OPTION] h0_scale = 1
# [OPTION] update_function = bfgs
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 19.25 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (4898, 2)
# [TEST DATA] shapes: (2100, 2)
# [TRAINING] Total epochs: 200
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |      2.2969 |       1.034 |      356 ms |
# |          50 |     0.13181 |     0.13315 |       57 ms |
# |         100 |     0.12711 |     0.12943 |      158 ms |
# |         150 |     0.12359 |     0.12754 |       66 ms |
# |         200 |     0.12059 |     0.12513 |       59 ms |
# ---------------------------------------------------------
#
# Softplus learn error mean 0.12113939755679878
# Softplus learn error std 0.0011860791764557528
# Softplus test error mean 0.12327233645650315
# Softplus test error std 0.006759649196923472
